# %% [markdown]
# 0. Predicting what number it is

# %%
# to load all the libraries and the dataset
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix

digits = load_digits()

# %%
# display some images
plt.figure(figsize=(30,6))

for index, (image, lable) in enumerate(zip(digits.data[0:5], digits.target[0:5])):
    plt.subplot(1,5,index+1)
    plt.imshow(np.reshape(image,(8,8)), cmap=plt.cm.gray)
    plt.title('Train: %i\n' %lable,fontsize=30)

# %%
# split the data into test and train
x_train, x_test,  y_train, y_test = train_test_split(digits.data, digits.target, test_size=0.20)

# %%
# train the model using x_train and y_train
log_model = LogisticRegression()
log_model.fit(x_train,y_train)
# Out:
# u:\Python\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# prdict for the x_test
y_predict = log_model.predict(x_test)
print(y_predict)
# determin the accuresy
accuresy = log_model.score(x_test,y_test)
print(accuresy)
# Out:
# [0 7 1 1 9 7 4 5 4 1 8 2 0 1 0 7 1 0 9 6 6 2 3 9 7 0 8 5 2 4 5 9 9 3 7 0 5
#  6 1 1 6 0 3 4 2 4 7 8 6 4 6 1 9 1 2 1 6 8 6 3 7 3 5 6 5 9 7 0 7 1 1 0 4 9
#  8 4 4 7 1 5 9 3 5 9 3 8 9 3 0 5 1 9 8 3 2 1 0 3 7 5 5 4 8 6 4 6 7 3 8 3 3
#  9 8 6 9 7 4 1 2 6 3 6 2 9 7 6 4 3 2 7 6 8 5 3 0 5 6 7 8 1 2 7 7 2 2 1 7 3
#  9 4 8 6 6 1 4 7 5 5 0 7 5 9 0 2 4 1 3 9 8 5 0 3 7 7 9 2 3 8 0 5 0 5 1 0 6
#  9 0 4 1 2 8 8 1 7 3 4 9 8 6 1 4 2 9 1 4 4 7 1 4 3 4 0 6 5 1 2 9 7 9 4 4 1
#  3 3 7 8 5 4 4 7 6 4 8 3 2 3 1 7 6 3 1 2 4 6 3 9 5 7 8 7 8 0 7 4 0 4 2 6 8
#  4 2 3 3 1 9 5 0 2 2 1 2 0 4 4 1 2 7 2 2 4 3 1 1 0 7 8 8 4 0 7 8 5 3 2 2 9
#  7 5 4 1 2 8 1 1 5 8 5 0 6 3 5 4 6 7 9 8 7 1 5 3 1 2 3 8 3 4 3 8 2 7 0 5 0
#  7 4 9 7 6 4 2 9 4 5 3 6 5 2 2 6 5 3 7 7 6 9 0 4 7 6 0]
# 0.9638888888888889

# %%
cm = cm = confusion_matrix(y_test, y_predict)

# %%
# represent the confusion matrix in the heatmap
plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt=".3f", linewidths=.5, square=True)
plt.ylabel('Actual lable')
plt.xlabel('Predicted lable')
all_sample_title='Accuracy Score:{0}'.format(accuresy)
plt.title(all_sample_title, size=15)
# Out:
# Text(0.5, 1.0, 'Accuracy Score:0.9638888888888889')
